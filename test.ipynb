# %%
import sys
from plot_utils import make_raincloud
import seaborn as sns
import pandas
import numpy
import matplotlib.pyplot as plt

# %%
# ?make_raincloud()
# Out:
# Signature: make_raincloud(x=None, y=None, hue=None, data=None, order=None, hue_order=None, bw=0.2, cut=0, scale='area', scale_hue=True, gridsize=100, width=0.8, inner=None, split=False, dodge=True, orient='y', linewidth=None, color=None, palette=None, saturation=0.75, ax=None, figsize=(6, 6), lablecounts=False, **kwargs)
# Docstring:
# Draw full raincloud using half_viol.
# labelcounts = True counts the number of items in each group and add it to x axis labels
# ! This adds a column to your dataframe
# >>> hv.make_raincloud(data=tips, x="day", y="total_bill", lablecounts=True)
# File:      ~/toolScripts/PtitPrince/plot_utils.py
# Type:      function

# %%
df = pandas.read_csv("https://data.bris.ac.uk/datasets/112g2vkxomjoo1l26vjmvnlexj/2016.08.14_AnxietyPaper_Data%20Sheet.csv"\
               ,sep=",")

ddf = pandas.melt(df, id_vars=["Participant"], value_vars = ["AngerUH", "DisgustUH", "FearUH", "HappyUH"],\
           var_name = "EmotionCondition", value_name = "Sensitivity")
ddf.head()
# Out:
#    Participant EmotionCondition  Sensitivity
# 0            1          AngerUH     0.297794
# 1            2          AngerUH     0.586806
# 2            3          AngerUH     0.389423
# 3            4          AngerUH     0.218750
# 4            5          AngerUH     0.520833

# %%
# %matplotlib inline
make_raincloud(data=ddf, y='Sensitivity', x='EmotionCondition', figsize=(6,4), lablecounts=True)
